# %%
#Logistic Regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

claimants=pd.read_csv("claimants.csv")
claimants
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# 5          97         0     1.0       1.0       0.0    35.0   0.309
# 6          10         0     0.0       1.0       0.0     9.0   3.538
# 7          36         0     1.0       1.0       0.0    34.0   4.881
# 8          51         1     1.0       1.0       0.0    60.0   0.874
# 9          55         1     0.0       1.0       0.0     NaN   0.350
# 10         61         0     1.0       1.0       0.0    37.0   6.190
# 11        148         0     0.0       1.0       0.0    41.0  19.610
# 12        150         1     0.0       1.0       0.0     7.0   1.678
# ...

# %%
claimants.isnull().sum()
# Out:
# CASENUM       0
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
claimants.shape
# Out:
# (1340, 7)

# %%
claimants.dropna().shape
# Out:
# (1096, 7)

# %%
claimants.CLMSEX.value_counts()
# Out:
# 1.0    742
# 0.0    586
# Name: CLMSEX, dtype: int64

# %%
claimants.CLMSEX.fillna(1,inplace=True)

# %%
claimants.SEATBELT.value_counts()
# Out:
# 0.0    1270
# 1.0      22
# Name: SEATBELT, dtype: int64

# %%
claimants.SEATBELT.fillna(1,inplace=True)

# %%
claimants.isnull().sum()
# Out:
# CASENUM       0
# ATTORNEY      0
# CLMSEX        0
# CLMINSUR     41
# SEATBELT      0
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
claimants.CLMAGE.mean()
# Out:
# 28.414422241529106

# %%
claimants.CLMINSUR.mean()
# Out:
# 0.9076212471131639

# %%
claimants.CLMAGE.fillna(28.4144,inplace=True)

# %%
claimants.CLMINSUR.fillna(0.9076,inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import classification_report
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
claimants.shape
# Out:
# (1340, 7)

# %%
claimants.columns
# Out:
# Index(['CASENUM', 'ATTORNEY', 'CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE',
#        'LOSS'],
#       dtype='object')

# %%
x=claimants.iloc[:,[1,2,3,4,5]]
x
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT   CLMAGE
# 0            0     0.0    1.0000       0.0  50.0000
# 1            1     1.0    0.0000       0.0  18.0000
# 2            1     0.0    1.0000       0.0   5.0000
# 3            0     0.0    1.0000       1.0  31.0000
# 4            1     0.0    1.0000       0.0  30.0000
# 5            0     1.0    1.0000       0.0  35.0000
# 6            0     0.0    1.0000       0.0   9.0000
# 7            0     1.0    1.0000       0.0  34.0000
# 8            1     1.0    1.0000       0.0  60.0000
# 9            1     0.0    1.0000       0.0  28.4144
# 10           0     1.0    1.0000       0.0  37.0000
# 11           0     0.0    1.0000       0.0  41.0000
# 12           1     0.0    1.0000       0.0   7.0000
# 13           0     1.0    1.0000       0.0  40.0000
# 14           1     1.0    1.0000       0.0  37.0000
# 15           1     1.0    0.0000       0.0   9.0000
# 16           1     1.0    1.0000       0.0  58.0000
# ...

# %%
y=claimants.iloc[:,0]
y
# Out:
# 0           5
# 1           3
# 2          66
# 3          70
# 4          96
# 5          97
# 6          10
# 7          36
# 8          51
# 9          55
# 10         61
# 11        148
# 12        150
# 13        150
# 14        169
# 15        171
# 16        334
# 17        360
# 18        376
# 19        401
# 20        479
# 21        480
# 22        550
# 23        569
# 24        580
# 25        608
# 26        603
# 27        606
# 28        607
# 29        630
#         ...
# 1310    33607
# 1311    33614
# 1312    33661
# 1313    33687
# 1314    33697
# 1315    33741
# 1316    33744
# 1317    33750
# 1318    33759
# 1319    33778
# 1320    33840
# 1321    33858
# 1322    33865
# 1323    33881
# 1324    33883
# 1325    34000
# 1326    34035
# 1327    34050
# 1328    34055
# 1329    34085
# 1330    34011
# 1331    34030
# 1332    34066
# 1333    34089
# 1334    34104
# 1335    34100
# 1336    34110
# 1337    34113
# 1338    34145
# 1339    34153
# ...

# %%
classifier=LogisticRegression()

# %%
classifier.fit(x,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.coef_
# Out:
# array([[-0.87019926, -1.04807931, -1.3845928 , -0.17632492, -0.07736579],
#        [-0.15114013, -0.35849705, -1.92757785, -0.16030714, -0.17971007],
#        [-0.83362805, -0.40748334, -1.32955538, -0.19850181, -0.16874623],
#        ...,
#        [-0.33250539, -0.5405184 , -1.49653566, -0.17850651, -0.08477047],
#        [-0.6949308 , -0.18861652, -1.83072768, -0.19802419, -0.3357673 ],
#        [-0.30213788, -0.50759198, -1.45975253, -0.17828864, -0.11090401]])

# %%
classifier.predict_proba(x)
# Out:
# array([[1.13086978e-03, 6.59381826e-06, 1.74634887e-05, ...,
#         6.05230080e-04, 5.03640856e-09, 1.97907052e-04],
#        [7.45044844e-04, 8.08257652e-04, 3.99400686e-04, ...,
#         1.60239848e-03, 5.70198855e-05, 1.24309986e-03],
#        [7.37319285e-04, 8.81465329e-04, 7.21133363e-04, ...,
#         9.41239453e-04, 4.39766517e-04, 1.02764558e-03],
#        ...,
#        [7.86251496e-04, 5.77914643e-05, 6.52839907e-05, ...,
#         1.29801306e-03, 1.69038838e-07, 6.02760868e-04],
#        [8.03460329e-04, 1.17458955e-03, 1.03031529e-03, ...,
#         1.08501178e-03, 6.83505686e-04, 1.05953365e-03],
#        [8.45612428e-04, 1.56149812e-04, 1.59819848e-04, ...,
#         1.49204377e-03, 1.86060379e-06, 8.76651172e-04]])

# %%
y_pred=classifier.predict(x)
y_pred
# Out:
# array([ 6409, 30903,   640, ...,  8400, 31056,  8400])

# %%
claimants["y_pred"]=y_pred

# %%
y_prob=pd.DataFrame(classifier.predict_proba(x.iloc[:,:]))
y_prob
# Out:
#           0             1         2         3         4         5     \
# 0     0.001131  6.593818e-06  0.000017  0.007512  0.000204  0.000014
# 1     0.000745  8.082577e-04  0.000399  0.001244  0.000588  0.000696
# 2     0.000737  8.814653e-04  0.000721  0.000528  0.000875  0.001067
# 3     0.001393  5.774247e-05  0.000120  0.003756  0.001177  0.000216
# 4     0.001129  1.046813e-04  0.000113  0.002484  0.000444  0.000149
# 5     0.001065  5.743129e-05  0.000123  0.004862  0.000551  0.000136
# 6     0.001266  4.929884e-04  0.000831  0.001330  0.001397  0.000808
# 7     0.001074  6.420180e-05  0.000136  0.004690  0.000581  0.000151
# 8     0.000551  4.717344e-06  0.000007  0.006316  0.000085  0.000010
# 9     0.001138  1.241341e-04  0.000131  0.002332  0.000480  0.000175
# 10    0.001043  4.586566e-05  0.000100  0.005214  0.000494  0.000110
# 11    0.001314  1.925470e-05  0.000046  0.005818  0.000353  0.000039
# 12    0.000845  8.241116e-04  0.000689  0.000661  0.000918  0.001011
# ...

# %%
new_df=pd.concat([claimants,y_prob],axis=1)
new_df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT   CLMAGE    LOSS  y_pred  \
# 0           5         0     0.0    1.0000       0.0  50.0000  34.940    6409
# 1           3         1     1.0    0.0000       0.0  18.0000   0.891   30903
# 2          66         1     0.0    1.0000       0.0   5.0000   0.330     640
# 3          70         0     0.0    1.0000       1.0  31.0000   0.037     905
# 4          96         1     0.0    1.0000       0.0  30.0000   0.038    6409
# 5          97         0     1.0    1.0000       0.0  35.0000   0.309       5
# 6          10         0     0.0    1.0000       0.0   9.0000   3.538     590
# 7          36         0     1.0    1.0000       0.0  34.0000   4.881       5
# 8          51         1     1.0    1.0000       0.0  60.0000   0.874    6409
# 9          55         1     0.0    1.0000       0.0  28.4144   0.350    6409
# 10         61         0     1.0    1.0000       0.0  37.0000   6.190       5
# ...

# %%
from sklearn.metrics import confusion_matrix
confusuion_matrix=confusion_matrix(y,y_pred)
print(confusion_matrix)
# Out:
# <function confusion_matrix at 0x1a0f4fcf28>

# %%
accuracy=sum(y==y_pred)/claimants.shape[0]
accuracy
# Out:
# 0.012686567164179104
